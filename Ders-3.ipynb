# %% [markdown]
# print(), input(), type(), int, String

# %%
print("Merhaba DCFL")
# Out:
# Merhaba DCFL

# %%
isim= input("Adını gir:")
print("Merhaba", isim)
# Out:
# Adını gir: Beyza
# Merhaba Beyza

# %%
sayi1 = int(input("Birinci sayıyı gir:"))
sayi2 = int(input("İkinci sayıyı gir:"))
toplama = sayi1+sayi2
print("girdiğin sayılar,", sayi1,"," ,sayi2, "\nToplamları:" ,toplama)
# Out:
# Birinci sayıyı gir: 2
# İkinci sayıyı gir: 3
# girdiğin sayılar, 2 , 3
# Toplamları: 5

# %% [markdown]
# Mantıksal Değerler
# True, False
# Boolean

# %%
6>4
# Out:
# True

# %%
5>=5
# Out:
# True

# %% [markdown]
# karşılaştyırma operatörü
# <
# >
# <=
# >=
# ==
# !=

# %%
4 != 3
# Out:
# True

# %%
4==4
# Out:
# True

# %%
4==3
# Out:
# False

# %%
type(True)
# Out:
# bool

# %%
type(4)
# Out:
# int

# %%
type(4>3)
# Out:
# bool

# %% [markdown]
# and operatörü(iki tane mantıksal değer de doğru ise True dönderir)

# %%
5>3 and 6>5
# Out:
# True

# %%
3>2 and 6<=3
# Out:
# False

# %% [markdown]
# or operatörü (iki tane mantıksal değeden sadece biri doğru ise True dönderir)

# %%
3>5 or 4!=5
# Out:
# True

# %%
6>7 or 17<15
# Out:
# False

# %% [markdown]
# not operatörü->değil

# %%
5>3
# Out:
# True

# %%
not 5>3
# Out:
# False

# %% [markdown]
# Koşul operatörleri
# if elif else

# %%
#kullanıcı girşi kontrol eden python programı
s_k_adi = "kedi"
s_sifre = "12345"

k_adi = input("Kullanıcı adını gir: ")
sifre = input("Şifreni gir:")

if s_k_adi == k_adi and s_sifre == sifre:
    print("Hoşgeldin", k_adi)
    
elif s_k_adi != k_adi and s_sifre ==sifre:
    print("Kullanıcı adını yanlış girdin")
    
elif s_k_adi == k_adi and s_sifre !=sifre:
    print("Şifreni yanlış girdin", k_adi)
else:
    print("İki alanı da yanlış girdin...lütfen bir daha dene!")
# Out:
# Kullanıcı adını gir:  kedii
# Şifreni gir: 234
# İki alanı da yanlış girdin...lütfen bir daha dene!

# %%
not ((5>4 or 9.8>=7) and (2.8>6 and 6.9<=6))
# Out:
# True

# %%
#sinema girişinde yaş kontrolü yapan program
yas = int(input("Yaşını gir:"))

if yas<18:
    print("Üzgünüm Sinemaya giremzsin!")
    
else: 
    print("Hoşgeldin, eğlenece başlasın")
# Out:
# Yaşını gir: 15
# Üzgünüm Sinemaya giremzsin!

# %% [markdown]
# formatlama metodu

# %%
ad = input("Adını gir")
print("Merhaba {}, hoş geldin".format(ad))
# Out:
# Adını gir Gülşen
# Merhaba Gülşen, hoş geldin

# %%
sayi1 =int(input("Birinci sayıyı gir:"))
sayi2 =int(input("İkinci sayıyı gir:"))
print("{} sayısı ile {} sayısının toplamı {} dır".format(sayi1, sayi2, sayi1+sayi2))
# Out:
# Birinci sayıyı gir: 56
# İkinci sayıyı gir: 78
# 56 sayısı ile 78 sayısının toplamı 134 dır

# %%
#Çok fonksiyonlu hesap makinesi

print("""*******************
Hesap makinesi
toplama için 1
Çıkarma için 2
Bölme için 3
çarpma için 4
üs alma için de 5 e basınız
""")

islem = input("İşlemini seç")


if islem !="1" or islem !="2" or islem !="3" or islem !="4" or islem !="5":
    print("Geçerli bir işlem seçilmedi")

    
sayi1 = int(input("Birinci sayıyı gir:"))
sayi2 = int(input("İkinci sayıyı gir:"))

if islem =="1":
    print("Toplama işlemi seçildi")
    print("{} sayıs ile {} nın toplamı {} dır.".format(sayi1, sayi2, sayi1+sayi2))
elif islem =="2":
    print("Çıkartma işlemi seçildi")
    print("{} sayıs ile {} nın farkı {} dır.".format(sayi1, sayi2, sayi1-sayi2))
elif islem =="3":
    print("Bölme işlemi seçildi")
    print("{} sayıs ile {} nın bölümü {} dır.".format(sayi1, sayi2, sayi1/sayi2))
elif islem =="4":
    print("Çarpma işlemi seçildi")
    print("{} sayıs ile {} nın çarpımı {} dır.".format(sayi1, sayi2, sayi1*sayi2))
elif islem =="5":
    print("Üs alma işlemi seçildi")
    print("{} sayısının {} kuvetti {} dır.".format(sayi1, sayi2, sayi1**sayi2))
else:
    print("Lütfen geçerli bir işlem seç!")
